# %%
import numpy as np
import tensorflow as tf

# 1. Cargar el dataset MNIST desde TensorFlow
# El dataset de MNIST contiene imágenes de 28x28 píxeles y etiquetas que corresponden a los dígitos 0-9
(X_train, Y_train), (X_test, Y_test) = tf.keras.datasets.mnist.load_data()

# Normalizamos las imágenes a valores entre 0 y 1
X_train = X_train / 255.0
X_test = X_test / 255.0

# Redimensionamos las imágenes de 28x28 a un vector de 784 elementos (28 * 28)
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

# Convertimos las etiquetas a formato one-hot (10 clases: 0-9)
Y_train = np.eye(10)[Y_train]
Y_test = np.eye(10)[Y_test]

# 2. Inicialización de los pesos y sesgos
# Capa 1: de 784 (entrada) a 128 neuronas (capa oculta)
W1 = np.random.randn(784, 128) * 0.01  # Peso de la capa de entrada a la capa oculta
b1 = np.zeros((1, 128))  # Sesgo de la capa oculta

# Capa 2: de 128 neuronas (capa oculta) a 10 neuronas (capa de salida)
W2 = np.random.randn(128, 10) * 0.01  # Peso de la capa oculta a la capa de salida
b2 = np.zeros((1, 10))  # Sesgo de la capa de salida

# 3. Definir funciones de activación

def relu(x):
    return np.maximum(0, x)  # ReLU

def softmax(x):
    e_x = np.exp(x - np.max(x, axis=1, keepdims=True))  # Estabilidad numérica
    return e_x / np.sum(e_x, axis=1, keepdims=True)  # Softmax

# 4. Función de entropía cruzada para calcular la pérdida
def cross_entropy_loss(y_true, y_pred):
    m = y_true.shape[0]  # Número de ejemplos
    loss = -np.sum(y_true * np.log(y_pred)) / m  # Fórmula de entropía cruzada
    return loss

# 5. Función para entrenamiento
def train(X_train, Y_train, epochs=10, learning_rate=0.01):
    global W1, b1, W2, b2
    for epoch in range(epochs):
        # Propagación hacia adelante
        z1 = np.dot(X_train, W1) + b1  # Capa oculta: Z = X * W + b
        a1 = relu(z1)  # Activación ReLU

        z2 = np.dot(a1, W2) + b2  # Capa de salida: Z = A1 * W + b
        a2 = softmax(z2)  # Activación Softmax

        # Calcular la pérdida
        loss = cross_entropy_loss(Y_train, a2)

        # Retropropagación
        dz2 = a2 - Y_train  # Derivada de la entropía cruzada con respecto a la activación de la capa de salida
        dW2 = np.dot(a1.T, dz2) / X_train.shape[0]  # Gradiente de los pesos de la capa de salida
        db2 = np.sum(dz2, axis=0, keepdims=True) / X_train.shape[0]  # Gradiente de los sesgos de la capa de salida

        dz1 = np.dot(dz2, W2.T) * (z1 > 0)  # Derivada de ReLU
        dW1 = np.dot(X_train.T, dz1) / X_train.shape[0]  # Gradiente de los pesos de la capa oculta
        db1 = np.sum(dz1, axis=0, keepdims=True) / X_train.shape[0]  # Gradiente de los sesgos de la capa oculta

        # Actualización de pesos y sesgos
        W1 -= learning_rate * dW1  # Actualización de W1
        b1 -= learning_rate * db1  # Actualización de b1

        W2 -= learning_rate * dW2  # Actualización de W2
        b2 -= learning_rate * db2  # Actualización de b2

        # Mostrar el progreso cada 100 épocas
        #if epoch % 100 == 0:
        print(f"Epoch {epoch}/{epochs}, Pérdida: {loss:.4f}")

# 6. Entrenar la red
train(X_train, Y_train, epochs=200, learning_rate=0.1)

# 7. Evaluar el modelo
# Propagación hacia adelante para las imágenes de prueba
z1_test = np.dot(X_test, W1) + b1
a1_test = relu(z1_test)

z2_test = np.dot(a1_test, W2) + b2
a2_test = softmax(z2_test)

# Predecir las clases
predictions = np.argmax(a2_test, axis=1)

# Comparar con las etiquetas verdaderas
accuracy = np.mean(np.argmax(Y_test, axis=1) == predictions)
print(f"Precisión en el conjunto de prueba: {accuracy * 100:.2f}%")
# Out:
# Epoch 0/200, Pérdida: 2.3025
# Epoch 1/200, Pérdida: 2.3014
# Epoch 2/200, Pérdida: 2.3003
# Epoch 3/200, Pérdida: 2.2991
# Epoch 4/200, Pérdida: 2.2979
# Epoch 5/200, Pérdida: 2.2967
# Epoch 6/200, Pérdida: 2.2954
# Epoch 7/200, Pérdida: 2.2940
# Epoch 8/200, Pérdida: 2.2926
# Epoch 9/200, Pérdida: 2.2911
# Epoch 10/200, Pérdida: 2.2895
# Epoch 11/200, Pérdida: 2.2877
# Epoch 12/200, Pérdida: 2.2859
# Epoch 13/200, Pérdida: 2.2839
# Epoch 14/200, Pérdida: 2.2818
# Epoch 15/200, Pérdida: 2.2795
# Epoch 16/200, Pérdida: 2.2770
# Epoch 17/200, Pérdida: 2.2743
# Epoch 18/200, Pérdida: 2.2714
# Epoch 19/200, Pérdida: 2.2683
# Epoch 20/200, Pérdida: 2.2649
# Epoch 21/200, Pérdida: 2.2612
# Epoch 22/200, Pérdida: 2.2573
# Epoch 23/200, Pérdida: 2.2530
# Epoch 24/200, Pérdida: 2.2485
# Epoch 25/200, Pérdida: 2.2435
# Epoch 26/200, Pérdida: 2.2382
# Epoch 27/200, Pérdida: 2.2324
# Epoch 28/200, Pérdida: 2.2263
# Epoch 29/200, Pérdida: 2.2197
# Epoch 30/200, Pérdida: 2.2126
# Epoch 31/200, Pérdida: 2.2050
# Epoch 32/200, Pérdida: 2.1969
# Epoch 33/200, Pérdida: 2.1882
# Epoch 34/200, Pérdida: 2.1790
# Epoch 35/200, Pérdida: 2.1692
# Epoch 36/200, Pérdida: 2.1588
# Epoch 37/200, Pérdida: 2.1478
# Epoch 38/200, Pérdida: 2.1361
# Epoch 39/200, Pérdida: 2.1238
# Epoch 40/200, Pérdida: 2.1108
# Epoch 41/200, Pérdida: 2.0971
# Epoch 42/200, Pérdida: 2.0828
# Epoch 43/200, Pérdida: 2.0678
# Epoch 44/200, Pérdida: 2.0520
# Epoch 45/200, Pérdida: 2.0356
# Epoch 46/200, Pérdida: 2.0185
# Epoch 47/200, Pérdida: 2.0006
# Epoch 48/200, Pérdida: 1.9821
# Epoch 49/200, Pérdida: 1.9629
# Epoch 50/200, Pérdida: 1.9430
# Epoch 51/200, Pérdida: 1.9224
# Epoch 52/200, Pérdida: 1.9013
# Epoch 53/200, Pérdida: 1.8794
# Epoch 54/200, Pérdida: 1.8570
# Epoch 55/200, Pérdida: 1.8341
# Epoch 56/200, Pérdida: 1.8106
# Epoch 57/200, Pérdida: 1.7867
# Epoch 58/200, Pérdida: 1.7624
# Epoch 59/200, Pérdida: 1.7377
# Epoch 60/200, Pérdida: 1.7128
# Epoch 61/200, Pérdida: 1.6876
# Epoch 62/200, Pérdida: 1.6622
# Epoch 63/200, Pérdida: 1.6368
# Epoch 64/200, Pérdida: 1.6113
# Epoch 65/200, Pérdida: 1.5858
# Epoch 66/200, Pérdida: 1.5604
# Epoch 67/200, Pérdida: 1.5352
# Epoch 68/200, Pérdida: 1.5101
# Epoch 69/200, Pérdida: 1.4853
# Epoch 70/200, Pérdida: 1.4608
# Epoch 71/200, Pérdida: 1.4367
# Epoch 72/200, Pérdida: 1.4130
# Epoch 73/200, Pérdida: 1.3896
# Epoch 74/200, Pérdida: 1.3667
# Epoch 75/200, Pérdida: 1.3443
# Epoch 76/200, Pérdida: 1.3224
# Epoch 77/200, Pérdida: 1.3009
# Epoch 78/200, Pérdida: 1.2800
# Epoch 79/200, Pérdida: 1.2596
# Epoch 80/200, Pérdida: 1.2397
# Epoch 81/200, Pérdida: 1.2204
# Epoch 82/200, Pérdida: 1.2015
# Epoch 83/200, Pérdida: 1.1832
# Epoch 84/200, Pérdida: 1.1654
# Epoch 85/200, Pérdida: 1.1480
# Epoch 86/200, Pérdida: 1.1312
# Epoch 87/200, Pérdida: 1.1149
# Epoch 88/200, Pérdida: 1.0990
# Epoch 89/200, Pérdida: 1.0835
# Epoch 90/200, Pérdida: 1.0686
# Epoch 91/200, Pérdida: 1.0540
# Epoch 92/200, Pérdida: 1.0399
# Epoch 93/200, Pérdida: 1.0261
# Epoch 94/200, Pérdida: 1.0128
# Epoch 95/200, Pérdida: 0.9999
# Epoch 96/200, Pérdida: 0.9873
# Epoch 97/200, Pérdida: 0.9751
# Epoch 98/200, Pérdida: 0.9632
# Epoch 99/200, Pérdida: 0.9516
# Epoch 100/200, Pérdida: 0.9404
# Epoch 101/200, Pérdida: 0.9295
# Epoch 102/200, Pérdida: 0.9189
# Epoch 103/200, Pérdida: 0.9086
# Epoch 104/200, Pérdida: 0.8985
# Epoch 105/200, Pérdida: 0.8888
# Epoch 106/200, Pérdida: 0.8793
# Epoch 107/200, Pérdida: 0.8700
# Epoch 108/200, Pérdida: 0.8610
# Epoch 109/200, Pérdida: 0.8523
# Epoch 110/200, Pérdida: 0.8437
# Epoch 111/200, Pérdida: 0.8354
# Epoch 112/200, Pérdida: 0.8273
# Epoch 113/200, Pérdida: 0.8194
# Epoch 114/200, Pérdida: 0.8117
# Epoch 115/200, Pérdida: 0.8042
# Epoch 116/200, Pérdida: 0.7969
# Epoch 117/200, Pérdida: 0.7898
# Epoch 118/200, Pérdida: 0.7828
# Epoch 119/200, Pérdida: 0.7760
# Epoch 120/200, Pérdida: 0.7694
# Epoch 121/200, Pérdida: 0.7629
# Epoch 122/200, Pérdida: 0.7566
# Epoch 123/200, Pérdida: 0.7504
# Epoch 124/200, Pérdida: 0.7444
# Epoch 125/200, Pérdida: 0.7385
# Epoch 126/200, Pérdida: 0.7327
# Epoch 127/200, Pérdida: 0.7271
# Epoch 128/200, Pérdida: 0.7216
# Epoch 129/200, Pérdida: 0.7162
# Epoch 130/200, Pérdida: 0.7110
# Epoch 131/200, Pérdida: 0.7058
# Epoch 132/200, Pérdida: 0.7008
# Epoch 133/200, Pérdida: 0.6959
# Epoch 134/200, Pérdida: 0.6911
# Epoch 135/200, Pérdida: 0.6863
# Epoch 136/200, Pérdida: 0.6817
# Epoch 137/200, Pérdida: 0.6772
# Epoch 138/200, Pérdida: 0.6727
# Epoch 139/200, Pérdida: 0.6684
# Epoch 140/200, Pérdida: 0.6641
# Epoch 141/200, Pérdida: 0.6600
# Epoch 142/200, Pérdida: 0.6559
# Epoch 143/200, Pérdida: 0.6519
# Epoch 144/200, Pérdida: 0.6479
# Epoch 145/200, Pérdida: 0.6441
# Epoch 146/200, Pérdida: 0.6403
# Epoch 147/200, Pérdida: 0.6366
# Epoch 148/200, Pérdida: 0.6329
# Epoch 149/200, Pérdida: 0.6293
# Epoch 150/200, Pérdida: 0.6258
# Epoch 151/200, Pérdida: 0.6224
# Epoch 152/200, Pérdida: 0.6190
# Epoch 153/200, Pérdida: 0.6157
# Epoch 154/200, Pérdida: 0.6124
# Epoch 155/200, Pérdida: 0.6092
# Epoch 156/200, Pérdida: 0.6060
# Epoch 157/200, Pérdida: 0.6029
# Epoch 158/200, Pérdida: 0.5999
# Epoch 159/200, Pérdida: 0.5969
# Epoch 160/200, Pérdida: 0.5939
# Epoch 161/200, Pérdida: 0.5910
# Epoch 162/200, Pérdida: 0.5882
# Epoch 163/200, Pérdida: 0.5854
# Epoch 164/200, Pérdida: 0.5826
# Epoch 165/200, Pérdida: 0.5799
# Epoch 166/200, Pérdida: 0.5772
# Epoch 167/200, Pérdida: 0.5746
# Epoch 168/200, Pérdida: 0.5720
# Epoch 169/200, Pérdida: 0.5695
# Epoch 170/200, Pérdida: 0.5670
# Epoch 171/200, Pérdida: 0.5645
# Epoch 172/200, Pérdida: 0.5621
# Epoch 173/200, Pérdida: 0.5597
# Epoch 174/200, Pérdida: 0.5573
# Epoch 175/200, Pérdida: 0.5550
# Epoch 176/200, Pérdida: 0.5527
# Epoch 177/200, Pérdida: 0.5504
# Epoch 178/200, Pérdida: 0.5482
# Epoch 179/200, Pérdida: 0.5460
# Epoch 180/200, Pérdida: 0.5439
# Epoch 181/200, Pérdida: 0.5417
# Epoch 182/200, Pérdida: 0.5396
# Epoch 183/200, Pérdida: 0.5376
# Epoch 184/200, Pérdida: 0.5355
# Epoch 185/200, Pérdida: 0.5335
# Epoch 186/200, Pérdida: 0.5315
# Epoch 187/200, Pérdida: 0.5296
# Epoch 188/200, Pérdida: 0.5277
# Epoch 189/200, Pérdida: 0.5258
# Epoch 190/200, Pérdida: 0.5239
# Epoch 191/200, Pérdida: 0.5220
# Epoch 192/200, Pérdida: 0.5202
# Epoch 193/200, Pérdida: 0.5184
# Epoch 194/200, Pérdida: 0.5166
# Epoch 195/200, Pérdida: 0.5149
# Epoch 196/200, Pérdida: 0.5131
# Epoch 197/200, Pérdida: 0.5114
# Epoch 198/200, Pérdida: 0.5097
# Epoch 199/200, Pérdida: 0.5081
# Precisión en el conjunto de prueba: 87.35%
